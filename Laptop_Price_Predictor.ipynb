# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/laptop_data.csv")

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns = 'Unnamed: 0')
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# ...

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), int64(1), object(7)
# memory usage: 112.1+ KB

# %%
sns.distplot(df['Price'])
# Out:
# <ipython-input-98-87e11caeb2c4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x = df['Company'], y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x = df['TypeName'], y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# <ipython-input-103-51888cb550e6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x = df['Inches'],y = df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['TouchScreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#      Unnamed: 0 Company   TypeName  Inches    ScreenResolution  \
# 401         401    Asus     Gaming    17.3   Full HD 1920x1080
# 377         377    Dell   Notebook    15.6            1366x768
# 177         177     MSI     Gaming    18.4   Full HD 1920x1080
# 838         838  Lenovo   Notebook    14.0            1366x768
# 495         495  Lenovo  Ultrabook    12.5  IPS Panel 1366x768
#
#                                        Cpu  Ram                Memory  \
# 401            Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 377  Intel Celeron Dual Core N3060 1.60GHz    4             500GB HDD
# 177            Intel Core i7 6920HQ 2.9GHz   32  512GB SSD +  1TB HDD
# 838   Intel Celeron Quad Core N3160 1.6GHz    4    16GB Flash Storage
# 495             Intel Core i5 6200U 2.3GHz    8             180GB SSD
#
#                          Gpu       OpSys  Weight      Price  TouchScreen
# 401  Nvidia GeForce GTX 1050  Windows 10     2.9   81465.12            0
# ...

# %%
df['TouchScreen'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='TouchScreen'>

# %%
df['Ips']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df['Ips'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Ips'>

# %%
sns.barplot(x = df['Ips'], y = df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand = True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#       Unnamed: 0 Company     TypeName  Inches             ScreenResolution  \
# 1091        1091      HP     Notebook    15.6                     1366x768
# 951          951    Dell    Ultrabook    14.0            Full HD 1920x1080
# 256          256      HP     Notebook    15.6                     1366x768
# 1103        1103      HP  Workstation    17.3  IPS Panel Full HD 1920x1080
# 1229        1229     MSI       Gaming    15.6            Full HD 1920x1080
#
#                                Cpu  Ram                Memory  \
# 1091      Intel Core i3 6006U 2GHz    4               1TB HDD
# 951     Intel Core i7 7600U 2.8GHz    8             256GB SSD
# 256   AMD A6-Series A6-9220 2.5GHz    8             128GB SSD
# 1103   Intel Core i7 6700HQ 2.6GHz    8               1TB HDD
# 1229   Intel Core i7 7700HQ 2.8GHz    8  128GB SSD +  1TB HDD
#
#                           Gpu       OpSys  Weight        Price  TouchScreen  \
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price             1303 non-null   float64
#  12  TouchScreen       1303 non-null   int64
#  13  Ips               1303 non-null   int64
#  14  X_res             1303 non-null   int64
#  15  Y_res             1303 non-null   int64
# ...

# %%
df['PPI'] = ((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']
df['PPI'].astype(float)
# Out:
# 0       226.983005
# 1       127.677940
# 2       141.211998
# 3       220.534624
# 4       226.983005
#            ...
# 1298    157.350512
# 1299    276.053530
# 1300    111.935204
# 1301    100.454670
# 1302    100.454670
# Name: PPI, Length: 1303, dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name']=df['Cpu'].apply(lambda x: " ".join(x.split()[0:3]))

# %%
def fetch_processor(text):
  if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
    return text
  else:
    if text.split()[0] == 'Intel':
      return 'Other Intel Processor'
    else:
      return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['Cpu brand'].value_counts().plot(kind ='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x =df['Cpu brand'], y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.drop(columns = ['Cpu', 'Cpu Name'],inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#    Ram               Memory                           Gpu  OpSys  Weight  \
# 0    8            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1    8  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2    8            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3   16            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4    8            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
# ...

# %%
df['Ram'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x =df['Ram'], y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
# Assume df['Memory'] already exists and contains storage values like '256GB SSD', '1TB HDD', etc.
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)

# Replace GB and TB to standardize memory sizes
df['Memory'] = df['Memory'].str.replace('GB', '')
df['Memory'] = df['Memory'].str.replace('TB', '000')

# Split the 'Memory' column on "+" to separate multiple storage units
new = df['Memory'].str.split("+", n=1, expand=True)

# Extract the 'first' and 'second' storage values
df["first"] = new[0].str.strip()
df["second"] = new[1].fillna("0").str.strip()

# Extract only numeric values for 'first' and 'second' before conversion
df["first_value"] = df["first"].str.extract('(\d+)').fillna(0).astype(int)
df["second_value"] = df["second"].str.extract('(\d+)').fillna(0).astype(int)

# Layer assignment: Check storage types from the text parts of 'first' and 'second'
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Calculate total HDD, SSD, Hybrid, and Flash Storage
df["HDD"] = df["first_value"] * df["Layer1HDD"] + df["second_value"] * df["Layer2HDD"]
df["SSD"] = df["first_value"] * df["Layer1SSD"] + df["second_value"] * df["Layer2SSD"]
df["Hybrid"] = df["first_value"] * df["Layer1Hybrid"] + df["second_value"] * df["Layer2Hybrid"]
df["Flash_Storage"] = df["first_value"] * df["Layer1Flash_Storage"] + df["second_value"] * df["Layer2Flash_Storage"]

# Drop unnecessary intermediate columns
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash_Storage',
                 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage', 'first_value', 'second_value'],
        inplace=True)

# Final DataFrame output
print(df)
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  Ram             Memory  \
# 0             IPS Panel Retina Display 2560x1600    8            128 SSD
# 1                                       1440x900    8  128 Flash Storage
# 2                              Full HD 1920x1080    8            256 SSD
# ...

# %%
df.sample(10)
# Out:
#      Unnamed: 0 Company   TypeName  Inches             ScreenResolution  Ram  \
# 916         916      HP   Notebook    13.3            Full HD 1920x1080    8
# 877         877  Xiaomi  Ultrabook    13.3  IPS Panel Full HD 1920x1080    8
# 931         931      HP  Ultrabook    12.5            Full HD 1920x1080    4
# 332         332    Asus   Notebook    14.0            Full HD 1920x1080    8
# 781         781    Asus     Gaming    17.3  IPS Panel Full HD 1920x1080   16
# 176         176    Acer   Notebook    15.6                     1366x768    4
# 679         679    Acer     Gaming    15.6            Full HD 1920x1080   16
# 500         500    Asus    Netbook    11.6                     1366x768    4
# 72           72    Dell   Notebook    15.6            Full HD 1920x1080    8
# 688         688      HP   Notebook    17.3  IPS Panel Full HD 1920x1080    6
#
#                   Memory                         Gpu         OpSys  Weight  \
# ...

# %%
df.drop(columns = ['Hybrid','Flash_Storage'], inplace = True)

# %%
df.drop(columns = ['Memory'], inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#    Ram                           Gpu  OpSys  Weight        Price  TouchScreen  \
# 0    8  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1    8        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2    8         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3   16            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4    8  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
# ...

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand']!= 'ARM']

# %%
sns.barplot(x =df['Gpu brand'], y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.drop(columns = ['Gpu brand'])
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  Ram  \
# 0             IPS Panel Retina Display 2560x1600    8
# 1                                       1440x900    8
# 2                              Full HD 1920x1080    8
# 3             IPS Panel Retina Display 2880x1800   16
# ...

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x = df['OpSys'], y =df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
def cat_os(inp):
  if inp == 'Windows 10' or inp == 'Windows 7 ' or inp == ' Windows 10 S':
    return 'Windows'
  elif inp == 'macOS' or inp == 'Mac OS X':
    return 'Mac'
  else:
    return 'Others/No Os/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)
# Out:
# <ipython-input-146-38671a3c07bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#    Ram                           Gpu  OpSys  Weight        Price  TouchScreen  \
# 0    8  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1    8        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2    8         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3   16            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4    8  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
# ...

# %%
df.drop(columns = ['OpSys'], inplace = True)
# Out:
# <ipython-input-148-671e705bf168>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = ['OpSys'], inplace = True)

# %%
sns.barplot(x = df['os'], y =df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# <ipython-input-150-05ee4c8848be>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x = df['Weight'], y = df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#              Unnamed: 0    Inches     Price  TouchScreen       Ips     X_res  \
# Unnamed: 0     1.000000 -0.086022  0.068784     0.049043 -0.025845 -0.044086
# Inches        -0.086022  1.000000  0.067329    -0.359514 -0.112726 -0.069875
# Price          0.068784  0.067329  1.000000     0.192917  0.253320  0.557369
# TouchScreen    0.049043 -0.359514  0.192917     1.000000  0.148026  0.350097
# Ips           -0.025845 -0.112726  0.253320     0.148026  1.000000  0.280588
# X_res         -0.044086 -0.069875  0.557369     0.350097  0.280588  1.000000
# Y_res         -0.056124 -0.092934  0.554591     0.355756  0.287404  0.994480
# PPI           -0.011373 -0.413055  0.475368     0.458571  0.299142  0.931478
# HDD           -0.020933  0.530468 -0.096891    -0.208766 -0.093588 -0.124872
# SSD           -0.057816 -0.109364  0.670660     0.257577  0.225311  0.528655
#
#                 Y_res       PPI       HDD       SSD
# Unnamed: 0  -0.056124 -0.011373 -0.020933 -0.057816
# ...

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
 sns.distplot(np.log(df['Price']))
# Out:
# <ipython-input-154-c1a82a4801f0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  Ram  \
# 0             IPS Panel Retina Display 2560x1600    8
# 1                                       1440x900    8
# 2                              Full HD 1920x1080    8
# 3             IPS Panel Retina Display 2880x1800   16
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size = 0.15,random_state = 2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# Ridge Regression

# %%
categorical_columns = [1,2,4,6,13,14,16,17]
numerical_columns = list(set(X_train.columns) - set(categorical_columns))

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), categorical_columns),
    ],
    remainder='passthrough'
)

step2 = Ridge(alpha = 10)

pipe = Pipeline(steps=[
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test, y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8406349401775868
# MAE 0.19852926616011943
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
categorical_columns = [1,2,4,6,13,14,16,17]
numerical_columns = list(set(X_train.columns) - set(categorical_columns))

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), categorical_columns),
    ],
    remainder='passthrough'
)

step2 = Lasso(alpha = 0.001)

pipe = Pipeline(steps=[
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test, y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8424028310558719
# MAE 0.19747720416909012
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# KNN

# %%
categorical_columns = [1,2,4,6,13,14,16,17]
numerical_columns = list(set(X_train.columns) - set(categorical_columns))

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), categorical_columns),
    ],
    remainder='passthrough'
)

step2 = KNeighborsRegressor(n_neighbors = 5)

pipe = Pipeline(steps=[
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test, y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.5252360397592478
# MAE 0.3241605958631878
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# Decision Tree

# %%
categorical_columns = [1,2,4,6,13,14,16,17]
numerical_columns = list(set(X_train.columns) - set(categorical_columns))

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), categorical_columns),
    ],
    remainder='passthrough'
)

step2 = DecisionTreeRegressor(max_depth = 8)

pipe = Pipeline(steps=[
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test, y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8050243247394048
# MAE 0.19533848148158803
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# Random Forest

# %%
categorical_columns = [1,2,4,6,13,14,16,17]
numerical_columns = list(set(X_train.columns) - set(categorical_columns))

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), categorical_columns),
    ],
    remainder='passthrough'
)

step2 = RandomForestRegressor(n_estimators = 100,random_state = 3,max_samples = 0.5,max_features = 0.75,max_depth = 15)

pipe = Pipeline(steps=[
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test, y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8774398087605204
# MAE 0.16527229732736293
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# Extra Trees

# %%
categorical_columns = [1,2,4,6,13,14,16,17]
numerical_columns = list(set(X_train.columns) - set(categorical_columns))

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), categorical_columns),
    ],
    remainder='passthrough'
)

step2 = ExtraTreesRegressor(n_estimators = 100,random_state = 3,max_samples = None,max_features = 0.75,max_depth = 15)

pipe = Pipeline(steps=[
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test, y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9003631358674493
# MAE 0.14717539332513097
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# AdaBoost

# %%
categorical_columns = [1,2,4,6,13,14,16,17]
numerical_columns = list(set(X_train.columns) - set(categorical_columns))

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), categorical_columns),
    ],
    remainder='passthrough'
)

step2 = AdaBoostRegressor(n_estimators = 15,learning_rate=1.0)

pipe = Pipeline(steps=[
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test, y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8045487268755986
# MAE 0.22491720884536526
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# GradientBoost

# %%
categorical_columns = [1,2,4,6,13,14,16,17]
numerical_columns = list(set(X_train.columns) - set(categorical_columns))

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), categorical_columns),
    ],
    remainder='passthrough'
)

step2 = GradientBoostingRegressor(n_estimators = 500)

pipe = Pipeline(steps=[
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test, y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8971121971965851
# MAE 0.15375714520167003
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# XgBoost

# %%
categorical_columns = [1,2,4,6,13,14,16,17]
numerical_columns = list(set(X_train.columns) - set(categorical_columns))

step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), categorical_columns),
    ],
    remainder='passthrough'
)

step2 = XGBRegressor(n_estimators = 45,max_depth = 5,learning_rate = 0.5)

pipe = Pipeline(steps=[
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test, y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.866994866172546
# MAE 0.1638322863118693
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# Export Model

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# import numpy as np
# import streamlit as st
# import pickle
# import math

# pipe = pickle.load(open('pipe.pkl','rb'))
# print(type(pipe))
# df = pickle.load(open('df.pkl','rb'))

# st.title('Laptop Predictor')

# company = st.selectbox('Brand',df['Company'].unique())
# type = st.selectbox('Type',df['TypeName'].unique())
# type = st.selectbox('RAM(in GB)',[2,4,6,8,12,16,24,32,64])
# weight = st.number_input('Weight of the laptop')
# touchscreen = st.selectbox('Touchscreen',['No','Yes'])
# ips = st.selectbox('IPS',['No','Yes'])
# screen_size = st.number_input('Screen Size')
# resolution = st.selectbox('Screen Resolution',['1920*1080','1366*768','1600*900',
#                           '3840*2160','3200*1800','2560*1600','2560*1440','2304*1440'])
# cpu = st.selectbox('Brand',df['Cpu brand'].unique())
# hdd = st.selectbox('HDD(in GB)',[0,128,256,512,1024,2048])
# ssd = st.selectbox('SSD(in GB)',[0,8,128,256,512,1024])
# gpu = st.selectbox('GPU',df['Gpu brand'].unique())
# os = st.selectbox('OS',df['os'].unique())

# if st.button('Predict Price'):

#     touchscreen = 1 if touchscreen == 'Yes' else 0
#     ips = 1 if ips == 'Yes' else 0

#     X_res = int(resolution.split('*')[0])
#     Y_res = int(resolution.split('*')[1])
#     ppi = ((X_res**2)+(Y_res**2))**0.5/screen_size
#     query = np.array([company,type,weight,touchscreen,ips,ppi,cpu,hdd,ssd,gpu,os])
#     query = query.reshape(1,-1)
#     st.title("The predicted price of the configuration is :"+ math.floor(np.exp(pipe.predict(query))))
