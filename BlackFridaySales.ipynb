# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/train.csv")
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17        10.0             A
# 1       1000001  P00248942      F   0-17        10.0             A
# 2       1000001  P00087842      F   0-17        10.0             A
# 3       1000001  P00085442      F   0-17        10.0             A
# 4       1000002  P00285442      M    55+        16.0             C
# ...         ...        ...    ...    ...         ...           ...
# 158101  1000425  P00120342      M  26-35        12.0             B
# 158102  1000426  P00085342      M  18-25         4.0             A
# 158103  1000426  P00338442      M  18-25         4.0             A
# 158104  1000426  P00294242      M  18-25         4.0             A
# 158105  1000426        NaN    NaN    NaN         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             0.0                 3.0
# 1                               2             0.0                 1.0
# 2                               2             0.0                12.0
# 3                               2             0.0                12.0
# 4                              4+             0.0                 8.0
# ...                           ...             ...                 ...
# 158101                          1             1.0                 5.0
# 158102                          1             1.0                10.0
# 158103                          1             1.0                 1.0
# 158104                          1             1.0                 4.0
# 158105                        NaN             NaN                 NaN
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN    8370.0
# 1                      6.0                14.0   15200.0
# 2                      NaN                 NaN    1422.0
# 3                     14.0                 NaN    1057.0
# 4                      NaN                 NaN    7969.0
# ...                    ...                 ...       ...
# 158101                17.0                 NaN    7167.0
# 158102                13.0                 NaN   23215.0
# 158103                16.0                 NaN   11524.0
# 158104                 5.0                 NaN    2183.0
# 158105                 NaN                 NaN       NaN
#
# [158106 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158106 entries, 0 to 158105
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     158106 non-null  int64
#  1   Product_ID                  158105 non-null  object
#  2   Gender                      158105 non-null  object
#  3   Age                         158105 non-null  object
#  4   Occupation                  158105 non-null  float64
#  5   City_Category               158105 non-null  object
#  6   Stay_In_Current_City_Years  158105 non-null  object
#  7   Marital_Status              158105 non-null  float64
#  8   Product_Category_1          158105 non-null  float64
#  9   Product_Category_2          109036 non-null  float64
#  10  Product_Category_3          48337 non-null   float64
#  11  Purchase                    158105 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 14.5+ MB

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         1
# Gender                             1
# Age                                1
# Occupation                         1
# City_Category                      1
# Stay_In_Current_City_Years         1
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2             49070
# Product_Category_3            109769
# Purchase                           1
# dtype: int64

# %%
df.dropna()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17        10.0             A
# 6       1000004  P00184942      M  46-50         7.0             B
# 13      1000005  P00145042      M  26-35        20.0             A
# 14      1000006  P00231342      F  51-55         9.0             A
# 16      1000006   P0096642      F  51-55         9.0             A
# ...         ...        ...    ...    ...         ...           ...
# 158089  1000424  P00019342      M  26-35        17.0             A
# 158094  1000425  P00113242      M  26-35        12.0             B
# 158097  1000425  P00057642      M  26-35        12.0             B
# 158098  1000425  P00002142      M  26-35        12.0             B
# 158099  1000425  P00198142      M  26-35        12.0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2             0.0                 1.0
# 6                               2             1.0                 1.0
# 13                              1             1.0                 1.0
# 14                              1             0.0                 5.0
# 16                              1             0.0                 2.0
# ...                           ...             ...                 ...
# 158089                          3             0.0                 1.0
# 158094                          1             1.0                 1.0
# 158097                          1             1.0                 1.0
# 158098                          1             1.0                 1.0
# 158099                          1             1.0                 2.0
#
#         Product_Category_2  Product_Category_3  Purchase
# 1                      6.0                14.0   15200.0
# 6                      8.0                17.0   19215.0
# 13                     2.0                 5.0   15665.0
# 14                     8.0                14.0    5378.0
# 16                     3.0                 4.0   13055.0
# ...                    ...                 ...       ...
# 158089                 6.0                15.0   11632.0
# 158094                 6.0                 8.0   15465.0
# 158097                15.0                16.0   15716.0
# 158098                 5.0                 8.0   11912.0
# 158099                 4.0                 9.0   12907.0
#
# [48337 rows x 12 columns]

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17        10.0             A
# 1       1000001  P00248942      F   0-17        10.0             A
# 2       1000001  P00087842      F   0-17        10.0             A
# 3       1000001  P00085442      F   0-17        10.0             A
# 4       1000002  P00285442      M    55+        16.0             C
# ...         ...        ...    ...    ...         ...           ...
# 158101  1000425  P00120342      M  26-35        12.0             B
# 158102  1000426  P00085342      M  18-25         4.0             A
# 158103  1000426  P00338442      M  18-25         4.0             A
# 158104  1000426  P00294242      M  18-25         4.0             A
# 158105  1000426        NaN    NaN    NaN         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             0.0                 3.0
# 1                               2             0.0                 1.0
# 2                               2             0.0                12.0
# 3                               2             0.0                12.0
# 4                              4+             0.0                 8.0
# ...                           ...             ...                 ...
# 158101                          1             1.0                 5.0
# 158102                          1             1.0                10.0
# 158103                          1             1.0                 1.0
# 158104                          1             1.0                 4.0
# 158105                        NaN             NaN                 NaN
#
#         Purchase
# 0         8370.0
# 1        15200.0
# 2         1422.0
# 3         1057.0
# 4         7969.0
# ...          ...
# 158101    7167.0
# 158102   23215.0
# 158103   11524.0
# 158104    2183.0
# 158105       NaN
#
# [158106 rows x 10 columns]

# %%
df['User_ID'].nunique()
# Out:
# 5879

# %%
df['Product_ID'].nunique()
# Out:
# 3428

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25', nan],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10., 16., 15.,  7., 20.,  9.,  1., 12., 17.,  0.,  3.,  4., 11.,
#         8., 19.,  2., 18.,  5., 14., 13.,  6., nan])

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B', nan], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0', nan], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3.,  1., 12.,  8.,  5.,  4.,  2.,  6., 14., 11., 13., 15.,  7.,
#        16., 18., 10., 17.,  9., nan])

# %%
df['Purchase'].sum()
# Out:
# 1472505809.0

# %%
df.columns
for column in df.columns:
  print(column, df[column].nunique())
# Out:
# User_ID 5879
# Product_ID 3428
# Gender 2
# Age 7
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 18
# Purchase 15197

# %%
data = pd.DataFrame({'Ratio' :[len(df[df['Gender'] == 'M']),len(df[df['Gender'] == 'F'])]}, index = ['Male','Female'])
data
# Out:
#          Ratio
# Male    119216
# Female   38889

# %%
data.plot.pie(y = 'Ratio', figsize = (6,6), autopct = "%.1f")
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby('Gender').size().plot(kind = 'pie', title = 'Gender Ratio', autopct = "%.1f", labels = 'gender',figsize = (6,6), shadow = True)
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df.groupby('Gender').size().plot(kind ='bar', figsize = (6,6))
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Age').size().plot(kind = 'bar', figsize=(12,6), title = 'Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
lst = []
for i in df['Age'].unique():
  lst.append((i,len(df[df['Age'] == i])))
lst
# Out:
# [('0-17', 4283),
#  ('55+', 6094),
#  ('26-35', 62940),
#  ('46-50', 13060),
#  ('51-55', 11106),
#  ('36-45', 31559),
#  ('18-25', 29063),
#  (nan, 0)]

# %%
data = pd.DataFrame(lst, columns = ['Age', 'Products'])
data
# Out:
#      Age  Products
# 0   0-17      4283
# 1    55+      6094
# 2  26-35     62940
# 3  46-50     13060
# 4  51-55     11106
# 5  36-45     31559
# 6  18-25     29063
# 7    NaN         0

# %%
data.plot.bar()
# Out:
# <Axes: >

# %%
df.groupby('Age').sum()['Purchase'].plot(kind = 'bar', figsize=(12,6), title = 'Amount spend by Age')
# Out:
# <Axes: title={'center': 'Amount spend by Age'}, xlabel='Age'>
